# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:33, 941KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
from random import random

# Set parameters
t= 1e-5

# Create Frequency Count of all words in the wordlist
counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word,count in counts.items()}
p_drop = {word: 1 - np.sqrt(t/freqs[word]) for word in counts}

# Subsample the words
train_words = [word for word in int_words if random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    import random
    #Draw random number
    window = random.randint(1, window_size+1)
    start = idx - window if (idx - window) > 0 else 0
    stop = idx + window
      
    
    return set(words[start:idx] + words[idx+1: stop])

# %%
get_target(['list', 'help', 'test', 'why', 'who', 'list', 'help', 'test', 'why', 'who'], 4, 5)
# Out:
# {'help', 'list', 'test', 'who', 'why'}

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed, 
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6587 0.0288 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6021 0.0250 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5171 0.0251 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5618 0.0246 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5362 0.0246 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5253 0.0248 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5814 0.0246 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5765 0.0248 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4800 0.0248 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4165 0.0251 sec/batch
# Nearest to their: house, incisive, ada, depravity, topeka, wild, requested, orman,
# Nearest to were: treacherously, colonization, dio, anthropologist, aalto, casualties, gad, trend,
# Nearest to see: semiconducting, concepts, bitola, aptidon, rossum, powered, buyoya, escudo,
# Nearest to two: weimar, assignments, aikidoka, kenneth, kaolinite, antibiotics, pcc, sampled,
# Nearest to so: retrospectively, downstream, styling, divergent, vociferous, came, keh, gracefully,
# Nearest to if: visits, schuschnigg, suomenlinna, pill, fiorina, jit, etz, symmetric,
# Nearest to into: trichloride, deconstructing, standardizing, fugitive, ratisbon, mondial, vestige, sensu,
# Nearest to new: acclaimed, grassy, theatres, dusty, pinned, juilliard, abolition, frente,
# Nearest to stage: mercy, trades, fossils, oratio, cockroach, scrat, megafauna, dramatization,
# Nearest to additional: goddesses, recon, masque, vcore, berenson, arius, weblogs, dundee,
# Nearest to woman: whip, forester, strict, puccini, synoptic, burzum, alas, designated,
# Nearest to grand: maas, shadowing, effigy, bres, refutation, salt, encapsulating, regents,
# Nearest to alternative: interplay, hens, wray, litoral, sell, lourdes, ekam, ferry,
# Nearest to bbc: modes, confucianism, discourage, bronchial, dubliners, invested, event, anjiro,
# Nearest to quite: chelating, falla, sepoy, participants, basov, affords, exclusive, vyanjana,
# Nearest to universe: decrypt, electrophoretic, energies, jin, simmons, galleys, indigenous, solids,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4993 0.0262 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3930 0.0248 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3736 0.0247 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2718 0.0250 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2099 0.0246 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1741 0.0248 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1336 0.0248 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0877 0.0248 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0128 0.0247 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0068 0.0250 sec/batch
# Nearest to their: house, wild, requested, notion, values, be, constructed, class,
# Nearest to were: state, colonization, trend, could, every, nothing, anthropologist, treacherously,
# Nearest to see: concepts, semiconducting, combinations, powered, fourth, rossum, external, imperial,
# Nearest to two: weimar, assignments, kenneth, picture, sampled, aikidoka, angle, phrases,
# Nearest to so: retrospectively, came, similar, styling, divergent, downstream, techno, crow,
# Nearest to if: visits, portion, how, any, pill, symmetric, other, annual,
# Nearest to into: sky, deconstructing, differ, trichloride, called, associations, biham, uses,
# Nearest to new: acclaimed, theatres, races, abolition, for, misleading, isthmus, miami,
# Nearest to stage: mercy, trades, similar, oratio, fossils, forthcoming, autocracy, percentage,
# Nearest to additional: goddesses, recon, spread, competition, masque, weblogs, rank, volleyball,
# Nearest to woman: whip, strict, designated, forester, paraphrased, fortune, synoptic, purged,
# Nearest to grand: maas, shadowing, effigy, salt, bres, refutation, correspondingly, sight,
# Nearest to alternative: interplay, sell, wray, ferry, litoral, display, hens, reputable,
# Nearest to bbc: modes, confucianism, event, discourage, dubliners, invested, holmes, bronchial,
# Nearest to quite: participants, exclusive, roughly, sepoy, affords, arrived, road, following,
# Nearest to universe: decrypt, indigenous, jin, simmons, energies, deacons, italians, stitched,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9379 0.0263 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9232 0.0248 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8771 0.0249 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8866 0.0248 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8016 0.0247 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8214 0.0249 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7991 0.0248 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7893 0.0247 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7888 0.0248 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7696 0.0247 sec/batch
# Nearest to their: wild, ada, buying, requested, incisive, notion, anita, house,
# Nearest to were: colonization, state, viable, treacherously, sacrifice, anthropologist, masterpiece, dio,
# Nearest to see: semiconducting, concepts, powered, rossum, combinations, arrangements, fourth, accented,
# Nearest to two: weimar, assignments, picture, officer, kenneth, andrews, phrases, aikidoka,
# Nearest to so: retrospectively, downstream, styling, divergent, came, gracefully, similar, cells,
# Nearest to if: visits, pill, ones, symmetric, portion, etz, jit, latinate,
# Nearest to into: indications, associations, sky, trichloride, ratisbon, deconstructing, fugitive, standardizing,
# Nearest to new: acclaimed, bonnie, abolition, dusty, theatres, races, isthmus, vandalism,
# Nearest to stage: mercy, trades, fossils, fortunate, oratio, forthcoming, neisse, autocracy,
# Nearest to additional: goddesses, masque, recon, competition, jesuit, spread, volleyball, wonderful,
# Nearest to woman: whip, strict, synoptic, designated, deep, fortune, folk, forester,
# Nearest to grand: maas, effigy, salt, shadowing, refutation, bres, analysing, regents,
# Nearest to alternative: interplay, ferry, sell, wray, developments, litoral, hens, display,
# Nearest to bbc: modes, invested, confucianism, discourage, dubliners, arpanet, argyll, bronchial,
# Nearest to quite: participants, exclusive, roughly, affords, cromwell, occupation, trials, sepoy,
# Nearest to universe: decrypt, indigenous, jin, energies, deacons, simmons, stitched, nerve,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7868 0.0260 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7546 0.0246 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7229 0.0247 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7417 0.0246 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7399 0.0248 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7196 0.0248 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7035 0.0248 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7240 0.0246 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7146 0.0247 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6671 0.0247 sec/batch
# Nearest to their: ada, plead, anita, requested, wild, buying, notion, incisive,
# Nearest to were: colonization, treacherously, sacrifice, princes, viable, dio, state, qumran,
# Nearest to see: semiconducting, concepts, rossum, powered, gigabit, accented, combinations, arrangements,
# Nearest to two: weimar, assignments, officer, picture, kenneth, emissary, andrews, swiss,
# Nearest to so: retrospectively, downstream, styling, divergent, gracefully, vociferous, similar, welding,
# Nearest to if: visits, etz, jit, symmetric, any, latinate, ones, pill,
# Nearest to into: trichloride, vestige, fugitive, standardizing, ratisbon, mondial, integrate, deconstructing,
# Nearest to new: bonnie, acclaimed, abolition, dusty, pinned, miami, biography, isthmus,
# Nearest to stage: mercy, trades, fortunate, forthcoming, oratio, dramatization, fossils, cockroach,
# Nearest to additional: goddesses, masque, recon, centrally, spread, weblogs, jesuit, ymca,
# Nearest to woman: whip, strict, alas, synoptic, fortune, folk, endanger, virginis,
# Nearest to grand: maas, effigy, refutation, shadowing, nunavut, regents, painter, bres,
# Nearest to alternative: interplay, hens, wray, sell, ferry, litoral, developments, reputable,
# Nearest to bbc: modes, invested, bronchial, dubliners, argyll, arpanet, discourage, purification,
# Nearest to quite: participants, affords, chelating, cromwell, exclusive, roughly, sepoy, withered,
# Nearest to universe: decrypt, energies, deacons, simmons, jin, indigenous, readable, marsh,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6687 0.0261 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6661 0.0247 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6260 0.0247 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6313 0.0248 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6527 0.0247 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6174 0.0247 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5723 0.0187 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5472 0.0247 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5229 0.0248 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4907 0.0247 sec/batch
# Nearest to their: ada, wild, plead, requested, ruthlessly, buying, anita, incisive,
# Nearest to were: colonization, aalto, sacrifice, viable, could, dio, treacherously, isles,
# Nearest to see: semiconducting, concepts, rossum, powered, accented, combinations, mormonism, arrangements,
# Nearest to two: weimar, assignments, officer, emissary, swiss, kenneth, eight, five,
# Nearest to so: retrospectively, downstream, divergent, styling, vociferous, relativistic, gracefully, welding,
# Nearest to if: visits, any, etz, symmetric, ones, latinate, jit, can,
# Nearest to into: trichloride, ratisbon, fugitive, vestige, standardizing, deconstructing, sky, biham,
# Nearest to new: bonnie, acclaimed, abolition, juilliard, morpheus, pinned, frente, became,
# Nearest to stage: mercy, trades, fortunate, dramatization, oratio, forthcoming, cockroach, fossils,
# Nearest to additional: goddesses, masque, recon, centrally, dunk, drinkers, weblogs, spread,
# Nearest to woman: whip, alas, fortune, virginis, fruity, telling, cucurbitaceae, folk,
# Nearest to grand: maas, effigy, nunavut, bres, painter, regents, shadowing, pastor,
# Nearest to alternative: interplay, hens, wray, reputable, litoral, plainfield, sell, penance,
# Nearest to bbc: modes, bronchial, argyll, dubliners, invested, arpanet, bulletins, mcfadden,
# Nearest to quite: participants, chelating, affords, keystroke, harmless, vyanjana, roughly, withered,
# Nearest to universe: decrypt, energies, deacons, simmons, jin, indigenous, solids, electrophoretic,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5104 0.0261 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5128 0.0247 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4596 0.0249 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5356 0.0249 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5154 0.0250 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4738 0.0247 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4717 0.0248 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4226 0.0250 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4369 0.0248 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4511 0.0249 sec/batch
# Nearest to their: ada, plead, ruthlessly, requested, wild, buying, shorty, happier,
# Nearest to were: colonization, aalto, could, sacrifice, unsold, biosafety, treacherously, isles,
# Nearest to see: semiconducting, concepts, powered, rossum, external, artificially, accented, arrangements,
# Nearest to two: weimar, assignments, matsumoto, five, emissary, syzygy, pcc, picture,
# Nearest to so: retrospectively, downstream, styling, divergent, welding, similar, demigods, relativistic,
# Nearest to if: visits, any, jit, can, ask, etz, ones, pill,
# Nearest to into: ratisbon, trichloride, standardizing, vestige, sky, integrate, deconstructing, fugitive,
# Nearest to new: bonnie, acclaimed, cooperated, giants, juilliard, miami, abolition, morpheus,
# Nearest to stage: mercy, trades, dramatization, fortunate, oratio, cockroach, fossils, forthcoming,
# Nearest to additional: goddesses, drinkers, recon, masque, dunk, qualitative, embedding, weblogs,
# Nearest to woman: alas, whip, virginis, fortune, archaeologically, telling, equipage, fruity,
# Nearest to grand: maas, effigy, nunavut, painter, bres, shadowing, regents, ladd,
# Nearest to alternative: interplay, hens, wray, developments, boying, reputable, plainfield, quieter,
# Nearest to bbc: modes, bronchial, argyll, arpanet, dubliners, bulletins, invested, jackpots,
# Nearest to quite: participants, chelating, affords, harmless, keystroke, roughly, withered, wakefulness,
# Nearest to universe: decrypt, energies, philandering, solids, simmons, readable, latency, electrophoretic,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4820 0.0264 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4194 0.0249 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4446 0.0247 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3973 0.0249 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4253 0.0246 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4388 0.0248 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3835 0.0248 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3843 0.0247 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4281 0.0247 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3759 0.0246 sec/batch
# Nearest to their: ada, plead, requested, ruthlessly, wild, happier, elicits, buying,
# Nearest to were: could, aalto, colonization, qumran, sacrifice, biosafety, unsold, highpoint,
# Nearest to see: concepts, semiconducting, external, accented, rossum, powered, pretends, arrangements,
# Nearest to two: five, weimar, est, assignments, eight, matsumoto, syzygy, emissary,
# Nearest to so: retrospectively, styling, welding, divergent, downstream, gracefully, similar, synthesize,
# Nearest to if: any, visits, ask, jit, pill, can, latinate, symmetric,
# Nearest to into: ratisbon, trichloride, standardizing, vestige, sky, deconstructing, integrate, rollers,
# Nearest to new: bonnie, acclaimed, scary, bozeman, frente, cooperated, miami, juilliard,
# Nearest to stage: mercy, trades, dramatization, fortunate, sarabande, oratio, cockroach, fossils,
# Nearest to additional: goddesses, masque, weblogs, dunk, drinkers, qualitative, recon, embedding,
# Nearest to woman: alas, fortune, whip, equipage, virginis, occult, telling, trio,
# Nearest to grand: maas, effigy, nunavut, bres, painter, ulm, shadowing, regents,
# Nearest to alternative: interplay, hens, wray, boying, developments, reputable, plainfield, litoral,
# Nearest to bbc: modes, bronchial, argyll, arpanet, jackpots, bulletins, invested, dubliners,
# Nearest to quite: participants, chelating, keystroke, affords, harmless, roughly, wakefulness, withered,
# Nearest to universe: decrypt, energies, latency, electrophoretic, simmons, solids, knuckles, philandering,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3533 0.0258 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3971 0.0248 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3852 0.0250 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3709 0.0248 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4173 0.0249 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3823 0.0249 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3945 0.0250 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3931 0.0248 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3302 0.0248 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3269 0.0248 sec/batch
# Nearest to their: ada, plead, requested, ruthlessly, them, to, happier, buying,
# Nearest to were: could, colonization, aalto, qumran, biosafety, sacrifice, peasants, highpoint,
# Nearest to see: external, semiconducting, concepts, gigabit, recipient, artificially, accented, aptidon,
# Nearest to two: five, est, eight, assignments, zero, weimar, syzygy, matsumoto,
# Nearest to so: retrospectively, divergent, styling, downstream, kam, gracefully, welding, vociferous,
# Nearest to if: any, visits, ask, jit, pill, latinate, can, dimension,
# Nearest to into: ratisbon, trichloride, standardizing, vestige, sky, deconstructing, wheelock, associations,
# Nearest to new: bonnie, bozeman, scary, frente, for, juilliard, cooperated, office,
# Nearest to stage: mercy, trades, dramatization, sarabande, fossils, fortunate, forthcoming, oratio,
# Nearest to additional: goddesses, dunk, recon, masque, weblogs, embedding, drinkers, quaternary,
# Nearest to woman: fertility, alas, fortune, virginis, whip, burzum, occult, archaeologically,
# Nearest to grand: maas, effigy, nunavut, ulm, suppressing, ladd, shadowing, regents,
# Nearest to alternative: interplay, hens, wray, developments, boying, reputable, plainfield, litoral,
# Nearest to bbc: modes, bronchial, argyll, arpanet, bulletins, jackpots, frankfort, carriacou,
# Nearest to quite: chelating, participants, keystroke, harmless, affords, wakefulness, wanton, ics,
# Nearest to universe: energies, decrypt, simmons, readable, philandering, electrophoretic, knuckles, solids,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3631 0.0262 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2928 0.0249 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3657 0.0249 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3819 0.0249 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3679 0.0249 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2903 0.0252 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3090 0.0248 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3322 0.0250 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2213 0.0251 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2880 0.0248 sec/batch
# Nearest to their: ada, plead, requested, ruthlessly, wild, shorty, happier, to,
# Nearest to were: could, colonization, aalto, qumran, biosafety, peasants, highpoint, devour,
# Nearest to see: external, concepts, semiconducting, recipient, gigabit, aptidon, describing, mormonism,
# Nearest to two: five, eight, zero, est, six, assignments, matsumoto, one,
# Nearest to so: retrospectively, divergent, gracefully, kam, styling, relativistic, welding, conductive,
# Nearest to if: any, visits, jit, ask, dimension, latinate, infinite, real,
# Nearest to into: ratisbon, trichloride, standardizing, sky, called, vestige, rollers, mondial,
# Nearest to new: bonnie, bozeman, miami, frente, scary, cooperated, redivided, for,
# Nearest to stage: mercy, dramatization, trades, sarabande, fortunate, forthcoming, cockroach, oratio,
# Nearest to additional: weblogs, goddesses, embedding, drinkers, masque, vcore, dunk, recon,
# Nearest to woman: fertility, fortune, hosius, whip, burzum, interacted, negotiators, alas,
# Nearest to grand: maas, effigy, nunavut, suppressing, ulm, regents, shadowing, ladd,
# Nearest to alternative: interplay, hens, wray, boying, plainfield, reputable, developments, gallura,
# Nearest to bbc: bronchial, argyll, modes, arpanet, bulletins, feast, frankfort, mcfadden,
# Nearest to quite: chelating, participants, harmless, keystroke, affords, wakefulness, wanton, anthropomorphic,
# Nearest to universe: energies, decrypt, solids, readable, simmons, latency, knuckles, electrophoretic,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3202 0.0263 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3153 0.0249 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3616 0.0121 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2562 0.0252 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2211 0.0250 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2185 0.0251 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2263 0.0249 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2019 0.0248 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2297 0.0250 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2174 0.0247 sec/batch
# Nearest to their: ada, ruthlessly, wild, plead, requested, happier, to, shorty,
# Nearest to were: could, qumran, colonization, biosafety, aalto, highpoint, isles, downplay,
# Nearest to see: external, concepts, semiconducting, mormonism, depicting, aptidon, recipient, chilli,
# Nearest to two: five, zero, eight, est, one, three, six, matsumoto,
# Nearest to so: retrospectively, kam, styling, divergent, gracefully, conductive, downstream, adversarial,
# Nearest to if: visits, any, ask, jit, dimension, protonated, latinate, varphi,
# Nearest to into: ratisbon, standardizing, trichloride, called, mondial, sky, heliozoa, souvenirs,
# Nearest to new: bozeman, for, miami, cooperated, bonnie, scary, frente, vim,
# Nearest to stage: dramatization, mercy, sarabande, trades, fortunate, forthcoming, orbital, oratio,
# Nearest to additional: vcore, embedding, weblogs, dunk, recon, drinkers, dundee, masque,
# Nearest to woman: fertility, fortune, hosius, alas, fruity, occult, vaughn, virginis,
# Nearest to grand: maas, effigy, suppressing, obligate, ladd, ulm, nunavut, merged,
# Nearest to alternative: interplay, hens, boying, wray, developments, pbs, plainfield, gallura,
# Nearest to bbc: bronchial, modes, arpanet, argyll, bulletins, feast, carriacou, lucas,
# Nearest to quite: chelating, participants, anthropomorphic, harmless, keystroke, wanton, wakefulness, affords,
# Nearest to universe: energies, decrypt, simmons, worlds, knuckles, deacons, readable, eternity,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2846 0.0262 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2458 0.0250 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2634 0.0251 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1344 0.0249 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1792 0.0247 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1694 0.0248 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1701 0.0245 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1821 0.0247 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2075 0.0247 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1666 0.0248 sec/batch
# Nearest to their: wild, ada, plead, professional, them, ruthlessly, horrifying, requested,
# Nearest to were: could, qumran, colonization, aalto, highpoint, biosafety, viable, isles,
# Nearest to see: external, concepts, semiconducting, aptidon, recipient, accented, chilli, mormonism,
# Nearest to two: five, zero, eight, est, one, three, six, nine,
# Nearest to so: retrospectively, kam, conductive, styling, gracefully, divergent, welding, downstream,
# Nearest to if: any, visits, ask, jit, iff, dimension, varphi, real,
# Nearest to into: ratisbon, trichloride, standardizing, called, vestige, rollers, sky, ripple,
# Nearest to new: bozeman, bonnie, cooperated, miami, lavey, frente, for, reno,
# Nearest to stage: sarabande, dramatization, forthcoming, mercy, trades, oratio, fortunate, fossils,
# Nearest to additional: embedding, dunk, vcore, weblogs, berenson, recon, drinkers, goddesses,
# Nearest to woman: fertility, hosius, alas, fortune, burzum, whip, occult, fruity,
# Nearest to grand: maas, effigy, suppressing, ulm, ladd, obligate, croydon, merged,
# Nearest to alternative: wray, interplay, boying, hens, developments, pbs, plainfield, reputable,
# Nearest to bbc: bronchial, arpanet, modes, bulletins, argyll, carriacou, frankfort, jackpots,
# Nearest to quite: chelating, participants, keystroke, anthropomorphic, harmless, wakefulness, wanton, affords,
# Nearest to universe: energies, decrypt, worlds, simmons, cosmic, latency, solids, knuckles,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1982 0.0263 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2429 0.0247 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1942 0.0249 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1591 0.0247 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1975 0.0248 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2087 0.0248 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1938 0.0247 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1525 0.0246 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1433 0.0247 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1792 0.0246 sec/batch
# Nearest to their: professional, ada, plead, horrifying, wild, happier, them, requested,
# Nearest to were: qumran, could, aalto, colonization, highpoint, biosafety, peasants, isles,
# Nearest to see: external, concepts, semiconducting, aptidon, gigabit, chilli, accented, pdf,
# Nearest to two: zero, five, eight, est, one, six, three, nine,
# Nearest to so: retrospectively, kam, styling, divergent, gracefully, conductive, welding, adversarial,
# Nearest to if: any, visits, ask, jit, real, varphi, can, dimension,
# Nearest to into: trichloride, ratisbon, called, standardizing, vestige, rollers, mondial, ripple,
# Nearest to new: bozeman, bonnie, for, cooperated, miami, lavey, frente, scary,
# Nearest to stage: sarabande, dramatization, fortunate, mercy, forthcoming, trades, oratio, arcane,
# Nearest to additional: weblogs, dunk, vcore, berenson, embedding, quaternary, drinkers, recon,
# Nearest to woman: fertility, fortune, hosius, alas, infant, male, interacted, burzum,
# Nearest to grand: maas, effigy, obligate, ladd, suppressing, generis, merged, esquerra,
# Nearest to alternative: hens, wray, boying, interplay, pbs, developments, reputable, resonators,
# Nearest to bbc: bronchial, arpanet, modes, bulletins, argyll, carriacou, invested, deane,
# Nearest to quite: chelating, participants, anthropomorphic, keystroke, wakefulness, wanton, harmless, affords,
# Nearest to universe: energies, decrypt, worlds, simmons, solids, electrophoretic, cosmic, emanation,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2080 0.0262 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2090 0.0248 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1947 0.0248 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2114 0.0250 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1581 0.0247 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1494 0.0248 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1834 0.0249 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1462 0.0249 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2064 0.0248 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2188 0.0251 sec/batch
# Nearest to their: plead, professional, wild, horrifying, ada, requested, to, they,
# Nearest to were: could, qumran, aalto, highpoint, isles, peasants, colonization, downplay,
# Nearest to see: external, concepts, aptidon, pdf, semiconducting, mormonism, gigabit, chilli,
# Nearest to two: five, zero, eight, one, three, six, est, four,
# Nearest to so: retrospectively, kam, styling, gracefully, curtius, divergent, adversarial, vociferous,
# Nearest to if: visits, any, jit, ask, daughter, approving, decide, varphi,
# Nearest to into: standardizing, trichloride, called, ratisbon, mondial, vestige, souvenirs, landtag,
# Nearest to new: bozeman, bonnie, for, frente, cooperated, redivided, miami, lavey,
# Nearest to stage: dramatization, sarabande, forthcoming, mercy, oratio, arcane, fortunate, trades,
# Nearest to additional: weblogs, dunk, berenson, vcore, embedding, recon, dundee, drinkers,
# Nearest to woman: fertility, fortune, infant, hosius, male, alas, whip, burzum,
# Nearest to grand: maas, effigy, ladd, suppressing, obligate, ulm, merged, parkland,
# Nearest to alternative: hens, wray, boying, interplay, pbs, developments, benito, reputable,
# Nearest to bbc: arpanet, bronchial, modes, argyll, bulletins, feast, carriacou, invested,
# Nearest to quite: chelating, participants, anthropomorphic, wanton, wakefulness, harmless, keystroke, affords,
# Nearest to universe: energies, worlds, solids, decrypt, simmons, emanation, cosmic, electrophoretic,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2189 0.0260 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1449 0.0248 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1610 0.0248 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1477 0.0246 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0427 0.0248 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1273 0.0248 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1525 0.0247 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1465 0.0248 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2094 0.0054 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1391 0.0248 sec/batch
# Nearest to their: professional, wild, ada, to, plead, horrifying, they, advance,
# Nearest to were: could, qumran, aalto, biosafety, highpoint, arouse, peasants, isles,
# Nearest to see: external, concepts, pdf, semiconducting, aptidon, chilli, depicting, gigabit,
# Nearest to two: zero, five, one, eight, three, six, four, nine,
# Nearest to so: retrospectively, kam, styling, gracefully, divergent, conductive, adversarial, diacritics,
# Nearest to if: any, visits, ask, jit, iff, decide, daughter, varphi,
# Nearest to into: called, trichloride, standardizing, ratisbon, the, souvenirs, vestige, mondial,
# Nearest to new: bozeman, for, bonnie, miami, vim, morpheus, frente, cooperated,
# Nearest to stage: sarabande, dramatization, forthcoming, arcane, oratio, actors, trades, mercy,
# Nearest to additional: weblogs, embedding, vcore, dunk, berenson, drinkers, dundee, recon,
# Nearest to woman: fertility, infant, male, hosius, fortune, repercussions, prevalence, rennie,
# Nearest to grand: maas, effigy, obligate, ulm, suppressing, merged, calcio, ladd,
# Nearest to alternative: hens, boying, wray, interplay, pbs, developments, benito, resonators,
# Nearest to bbc: arpanet, bulletins, modes, bronchial, feast, argyll, carriacou, deane,
# Nearest to quite: chelating, anthropomorphic, participants, wakefulness, wanton, keystroke, affords, harmless,
# Nearest to universe: energies, worlds, solids, decrypt, simmons, emanation, kepler, cosmic,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0748 0.0265 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0573 0.0248 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1017 0.0249 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0462 0.0245 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0955 0.0247 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0354 0.0249 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1058 0.0250 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0989 0.0247 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1215 0.0250 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0398 0.0249 sec/batch
# Nearest to their: professional, they, wild, to, advance, ada, them, horrifying,
# Nearest to were: could, qumran, aalto, isles, biosafety, arouse, highpoint, benefited,
# Nearest to see: external, concepts, semiconducting, chilli, aptidon, depicting, gigabit, pdf,
# Nearest to two: zero, five, one, eight, three, six, four, nine,
# Nearest to so: retrospectively, kam, gracefully, styling, conductive, divergent, downstream, diacritics,
# Nearest to if: ask, any, visits, decide, jit, iff, daughter, can,
# Nearest to into: called, the, ratisbon, trichloride, standardizing, fain, landtag, vestige,
# Nearest to new: bozeman, miami, giants, for, cooperated, bonnie, vim, frente,
# Nearest to stage: sarabande, dramatization, forthcoming, trades, arcane, oratio, orbital, actors,
# Nearest to additional: vcore, berenson, weblogs, embedding, dunk, volleyball, dundee, drinkers,
# Nearest to woman: fertility, infant, male, hosius, fortune, prevalence, fruity, alas,
# Nearest to grand: maas, effigy, merged, obligate, ulm, suppressing, ladd, parkland,
# Nearest to alternative: boying, wray, hens, pbs, interplay, benito, developments, reputable,
# Nearest to bbc: arpanet, bulletins, modes, bronchial, news, carriacou, deane, website,
# Nearest to quite: chelating, participants, anthropomorphic, wakefulness, wanton, keystroke, harmless, affords,
# Nearest to universe: energies, cosmic, worlds, solids, electrophoretic, decrypt, emanation, simmons,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0291 0.0261 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0744 0.0251 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0273 0.0247 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0699 0.0248 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0855 0.0249 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0662 0.0247 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0713 0.0247 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1037 0.0248 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0570 0.0247 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0627 0.0246 sec/batch
# Nearest to their: professional, they, wild, them, horrifying, advance, ada, voucher,
# Nearest to were: could, qumran, aalto, isles, arouse, colonization, stillborn, highpoint,
# Nearest to see: external, concepts, semiconducting, chilli, gigabit, also, pdf, depicting,
# Nearest to two: zero, five, one, three, eight, six, four, nine,
# Nearest to so: retrospectively, kam, gracefully, styling, conductive, welding, divergent, fits,
# Nearest to if: any, iff, ask, can, visits, jit, varphi, real,
# Nearest to into: called, trichloride, vestige, ratisbon, standardizing, ripple, fain, landtag,
# Nearest to new: bozeman, bonnie, miami, lavey, morpheus, frente, for, awash,
# Nearest to stage: sarabande, dramatization, oratio, trades, forthcoming, arcane, fortunate, mercy,
# Nearest to additional: vcore, berenson, weblogs, dunk, embedding, dundee, bibliographies, qualitative,
# Nearest to woman: fertility, infant, male, hosius, fortune, expectancy, burzum, sexuality,
# Nearest to grand: maas, effigy, merged, ulm, obligate, collectivit, ladd, esquerra,
# Nearest to alternative: boying, wray, pbs, hens, benito, interplay, developments, resonators,
# Nearest to bbc: arpanet, bulletins, bronchial, modes, carriacou, news, weekly, feast,
# Nearest to quite: chelating, participants, anthropomorphic, wakefulness, wanton, keystroke, harmless, affords,
# Nearest to universe: energies, worlds, cosmic, solids, decrypt, emanation, simmons, electrophoretic,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0546 0.0262 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0787 0.0250 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1002 0.0252 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0723 0.0248 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0608 0.0250 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0532 0.0250 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0675 0.0247 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0636 0.0248 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0751 0.0250 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0795 0.0248 sec/batch
# Nearest to their: professional, they, them, wild, advance, horrifying, ancestress, baptisms,
# Nearest to were: qumran, could, isles, aalto, peasants, was, colonization, arouse,
# Nearest to see: external, also, chilli, pdf, depicting, concepts, gigabit, aptidon,
# Nearest to two: zero, five, three, one, eight, six, est, nine,
# Nearest to so: retrospectively, kam, styling, conductive, gracefully, clear, welding, it,
# Nearest to if: visits, any, can, iff, jit, ask, approving, varphi,
# Nearest to into: called, fain, landtag, ratisbon, vestige, the, trichloride, and,
# Nearest to new: bozeman, bonnie, for, lavey, frente, morpheus, redivided, miami,
# Nearest to stage: sarabande, dramatization, oratio, classifying, trades, fortunate, arcane, forthcoming,
# Nearest to additional: vcore, berenson, dunk, weblogs, volleyball, embedding, drinkers, dundee,
# Nearest to woman: fertility, male, infant, hosius, expectancy, fortune, adjective, rate,
# Nearest to grand: maas, effigy, merged, obligate, parkland, kristina, esquerra, ulm,
# Nearest to alternative: boying, wray, hens, pbs, developments, benito, interplay, resonators,
# Nearest to bbc: bulletins, arpanet, modes, bronchial, news, carriacou, feast, argyll,
# Nearest to quite: chelating, participants, anthropomorphic, wanton, keystroke, wakefulness, harmless, affords,
# Nearest to universe: energies, worlds, cosmic, solids, electrophoretic, simmons, kepler, halley,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0864 0.0265 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9997 0.0250 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0297 0.0247 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0800 0.0253 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0640 0.0253 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1391 0.0253 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1449 0.0249 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0435 0.0247 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0567 0.0246 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0553 0.0246 sec/batch
# Nearest to their: professional, they, wild, horrifying, advance, them, ancestress, pacified,
# Nearest to were: qumran, aalto, could, peasants, isles, arouse, was, highpoint,
# Nearest to see: external, pdf, also, chilli, aptidon, depicting, gigabit, concepts,
# Nearest to two: zero, five, three, one, eight, six, est, four,
# Nearest to so: kam, retrospectively, styling, gracefully, conductive, divergent, combos, diacritics,
# Nearest to if: any, can, iff, visits, jit, varphi, ones, decide,
# Nearest to into: called, fain, trichloride, ratisbon, landtag, vestige, first, ripple,
# Nearest to new: bozeman, bonnie, miami, vim, nebraska, frente, morpheus, for,
# Nearest to stage: sarabande, dramatization, oratio, arcane, forthcoming, orbital, fortunate, trades,
# Nearest to additional: vcore, weblogs, berenson, dunk, embedding, bibliographies, volleyball, dundee,
# Nearest to woman: fertility, male, infant, expectancy, hosius, adjective, fortune, rate,
# Nearest to grand: maas, effigy, merged, obligate, parkland, suppressing, kristina, ulm,
# Nearest to alternative: boying, wray, hens, pbs, benito, resonators, interplay, developments,
# Nearest to bbc: feast, day, bulletins, bronchial, carriacou, argyll, modes, arpanet,
# Nearest to quite: chelating, anthropomorphic, participants, keystroke, wanton, wakefulness, affords, harmless,
# Nearest to universe: energies, worlds, cosmic, solids, kepler, simmons, electrophoretic, wildstorm,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0280 0.0260 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0393 0.0249 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0740 0.0247 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0522 0.0247 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0811 0.0249 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0604 0.0237 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0432 0.0251 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9906 0.0253 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0112 0.0249 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9732 0.0251 sec/batch
# Nearest to their: they, professional, horrifying, them, ancestress, wild, advance, innately,
# Nearest to were: could, qumran, was, aalto, arouse, trebuchet, isles, peasants,
# Nearest to see: external, also, chilli, concepts, pdf, depicting, semiconducting, aptidon,
# Nearest to two: zero, five, three, one, eight, six, seven, four,
# Nearest to so: retrospectively, kam, styling, clear, conductive, gracefully, curtius, divergent,
# Nearest to if: visits, any, jit, can, iff, ones, decide, ask,
# Nearest to into: called, first, the, depending, fain, ripple, trichloride, orgasm,
# Nearest to new: bozeman, awash, bonnie, for, miami, morpheus, giants, loveline,
# Nearest to stage: sarabande, oratio, orbital, dramatization, arcane, forthcoming, actors, fortunate,
# Nearest to additional: vcore, weblogs, berenson, embedding, dunk, volleyball, bibliographies, drinkers,
# Nearest to woman: fertility, infant, male, hosius, prevalence, adjective, expectancy, rate,
# Nearest to grand: maas, effigy, obligate, merged, kristina, parkland, aleksei, rowdy,
# Nearest to alternative: boying, wray, hens, pbs, benito, interplay, resonators, additive,
# Nearest to bbc: feast, day, listing, bulletins, bronchial, modes, arpanet, carriacou,
# Nearest to quite: chelating, anthropomorphic, participants, keystroke, wakefulness, wanton, falla, affords,
# Nearest to universe: energies, worlds, cosmic, solids, simmons, wildstorm, emanation, decrypt,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9850 0.0265 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9522 0.0247 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0390 0.0252 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0580 0.0251 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0183 0.0249 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0192 0.0251 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9248 0.0248 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9748 0.0251 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9802 0.0251 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9966 0.0248 sec/batch
# Nearest to their: they, professional, wild, them, horrifying, advance, ancestress, dreidel,
# Nearest to were: was, could, qumran, benefited, trebuchet, grissom, aalto, terminate,
# Nearest to see: external, also, chilli, semiconducting, concepts, links, depicting, accented,
# Nearest to two: zero, five, three, one, eight, six, four, seven,
# Nearest to so: retrospectively, kam, conductive, gracefully, styling, clear, divergent, curtius,
# Nearest to if: any, can, iff, jit, ask, decide, varphi, ones,
# Nearest to into: called, first, depending, trichloride, the, fain, and, ripple,
# Nearest to new: bozeman, bonnie, miami, giants, awash, nebraska, rivalry, loveline,
# Nearest to stage: sarabande, oratio, orbital, dramatization, arcane, forthcoming, actors, fortunate,
# Nearest to additional: berenson, vcore, weblogs, embedding, dunk, volleyball, drinkers, bibliographies,
# Nearest to woman: fertility, infant, male, prevalence, hosius, rate, expectancy, adjective,
# Nearest to grand: maas, effigy, merged, parkland, kristina, rowdy, obligate, aleksei,
# Nearest to alternative: boying, wray, pbs, hens, benito, resonators, interplay, developments,
# Nearest to bbc: feast, bulletins, day, bronchial, listing, modes, arpanet, broadcasts,
# Nearest to quite: chelating, anthropomorphic, wakefulness, participants, wanton, falla, keystroke, basenjis,
# Nearest to universe: energies, worlds, cosmic, solids, wildstorm, electrophoretic, simmons, decrypt,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0152 0.0261 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0077 0.0247 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9735 0.0247 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0164 0.0246 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0419 0.0246 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9664 0.0246 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0132 0.0248 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0073 0.0247 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0066 0.0246 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0135 0.0249 sec/batch
# Nearest to their: they, professional, them, horrifying, wild, advance, ancestress, baptisms,
# Nearest to were: qumran, could, was, aalto, arouse, isles, abiathar, early,
# Nearest to see: external, also, chilli, links, semiconducting, aptidon, monkey, depicting,
# Nearest to two: zero, five, three, one, eight, six, four, seven,
# Nearest to so: retrospectively, kam, gracefully, clear, styling, conductive, depressed, irrelevant,
# Nearest to if: any, can, iff, ones, varphi, approving, visits, jit,
# Nearest to into: called, trichloride, first, depending, landtag, tumbling, vestige, fain,
# Nearest to new: bozeman, bonnie, seanad, pennsylvania, nebraska, loveline, miami, awash,
# Nearest to stage: sarabande, oratio, arcane, orbital, forthcoming, dramatization, actors, warfare,
# Nearest to additional: vcore, weblogs, berenson, embedding, dunk, volleyball, okina, drinkers,
# Nearest to woman: fertility, infant, male, prevalence, hosius, rate, expectancy, burzum,
# Nearest to grand: maas, effigy, obligate, merged, kristina, parkland, aleksei, relays,
# Nearest to alternative: wray, boying, pbs, hens, resonators, additive, benito, developments,
# Nearest to bbc: feast, day, bulletins, listing, modes, broadcasts, arpanet, bronchial,
# Nearest to quite: chelating, anthropomorphic, keystroke, participants, wanton, wakefulness, falla, much,
# Nearest to universe: worlds, energies, cosmic, solids, wildstorm, simmons, electrophoretic, decrypt,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0275 0.0262 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0197 0.0247 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9970 0.0247 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0049 0.0248 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0032 0.0249 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9985 0.0248 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0108 0.0248 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9616 0.0251 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9795 0.0248 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0452 0.0249 sec/batch
# Nearest to their: they, professional, them, horrifying, advance, to, wild, ancestress,
# Nearest to were: could, was, qumran, early, benefited, peasants, trebuchet, isles,
# Nearest to see: external, also, links, chilli, pdf, list, semiconducting, ethnologue,
# Nearest to two: zero, five, one, three, eight, four, six, seven,
# Nearest to so: retrospectively, kam, styling, clear, gracefully, conductive, psycholinguistics, diacritics,
# Nearest to if: can, any, iff, visits, varphi, ones, approving, decide,
# Nearest to into: called, first, landtag, the, and, depending, trichloride, fain,
# Nearest to new: bozeman, bonnie, seanad, loveline, pennsylvania, vim, outstripped, backtracking,
# Nearest to stage: sarabande, oratio, autocracy, actors, arcane, orbital, esteem, performed,
# Nearest to additional: vcore, dunk, weblogs, berenson, embedding, okina, usually, drinkers,
# Nearest to woman: fertility, infant, male, expectancy, adjective, rate, hosius, prevalence,
# Nearest to grand: maas, effigy, obligate, merged, kristina, parkland, relays, rowdy,
# Nearest to alternative: wray, boying, pbs, hens, additive, resonators, benito, survivors,
# Nearest to bbc: feast, day, listing, bulletins, modes, carriacou, links, bronchial,
# Nearest to quite: chelating, anthropomorphic, wakefulness, keystroke, wanton, participants, basenjis, much,
# Nearest to universe: worlds, energies, cosmic, solids, wildstorm, simmons, electrophoretic, emanation,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.0151 0.0265 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1045 0.0248 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0414 0.0246 sec/batch
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9054 0.0253 sec/batch
# Nearest to their: they, them, to, plesiosaurs, any, are, horrifying, family,
# Nearest to were: was, could, had, early, have, as, least, qumran,
# Nearest to see: external, also, links, list, in, of, the, describing,
# Nearest to two: zero, three, five, one, four, six, eight, seven,
# Nearest to so: when, depressed, abandon, gracefully, not, lubrication, lidocaine, hopefully,
# Nearest to if: can, any, iff, nhadau, automatically, approving, varphi, think,
# Nearest to into: first, and, the, called, depending, which, tumbling, eventually,
# Nearest to new: york, outstripped, in, that, bonnie, bozeman, pennsylvania, for,
# Nearest to stage: performed, arcane, formation, sarabande, autocracy, actors, primetime, gametophyte,
# Nearest to additional: usually, okina, vcore, metalloids, primary, postalveolar, qualitative, volleyball,
# Nearest to woman: fertility, infant, adjective, male, rate, expectancy, nationality, female,
# Nearest to grand: kristina, maas, vytautas, prix, obligate, rzeczypospolitej, effigy, rump,
# Nearest to alternative: boying, additive, pbs, complementary, wray, funkadelic, survivors, kcr,
# Nearest to bbc: listing, feast, day, deane, news, bulletins, broadcasts, gregorian,
# Nearest to quite: falla, much, anthropomorphic, reputation, chelating, lite, keystroke, developed,
# Nearest to universe: worlds, energies, cosmic, inflation, wildstorm, jin, cosmological, closer,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8571 0.0268 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8572 0.0251 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8820 0.0251 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8603 0.0256 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8681 0.0253 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8842 0.0253 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8793 0.0254 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8366 0.0253 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8943 0.0251 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8703 0.0252 sec/batch
# Nearest to their: they, them, to, plesiosaurs, any, are, advance, horrifying,
# Nearest to were: was, had, could, early, as, have, least, been,
# Nearest to see: external, also, links, list, in, of, the, is,
# Nearest to two: zero, three, five, one, four, six, seven, eight,
# Nearest to so: abandon, depressed, when, ask, clear, not, it, adolfo,
# Nearest to if: can, nhadau, iff, any, varphi, automatically, homeomorphic, approving,
# Nearest to into: the, and, first, called, of, which, depending, eventually,
# Nearest to new: york, bonnie, outstripped, in, that, lamarckian, based, bozeman,
# Nearest to stage: performed, autocracy, formation, arcane, sarabande, gametophyte, actors, phases,
# Nearest to additional: usually, neuroses, sayyed, dunk, vcore, okina, berenson, qualitative,
# Nearest to woman: fertility, infant, adjective, male, rate, expectancy, nationality, female,
# Nearest to grand: kristina, prix, maas, vytautas, obligate, rump, kuznetsov, rzeczypospolitej,
# Nearest to alternative: boying, additive, pbs, funkadelic, survivors, wray, used, kcr,
# Nearest to bbc: listing, feast, day, deane, news, broadcasts, links, bulletins,
# Nearest to quite: anthropomorphic, falla, much, lite, reputation, chelating, feudatories, developed,
# Nearest to universe: worlds, energies, cosmic, wildstorm, inflation, even, jin, cosmological,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8663 0.0265 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8505 0.0251 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8209 0.0254 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8267 0.0252 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9278 0.0253 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8556 0.0251 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9809 0.0257 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9086 0.0252 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9156 0.0251 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8399 0.0250 sec/batch
# Nearest to their: they, them, any, to, horrifying, plesiosaurs, racemic, are,
# Nearest to were: was, had, could, early, as, have, least, been,
# Nearest to see: external, links, also, list, of, in, iarc, is,
# Nearest to two: zero, five, three, one, four, seven, six, eight,
# Nearest to so: not, abandon, if, ask, adolfo, depressed, always, clear,
# Nearest to if: can, nhadau, any, iff, varphi, so, automatically, homeomorphic,
# Nearest to into: and, the, first, called, eventually, tumbling, which, depending,
# Nearest to new: york, outstripped, bonnie, in, based, that, accepted, the,
# Nearest to stage: performed, autocracy, formation, gametophyte, actors, videography, arcane, sarabande,
# Nearest to additional: usually, volleyball, okina, sayyed, qualitative, berenson, cleric, dunk,
# Nearest to woman: fertility, adjective, infant, male, rate, nationality, expectancy, children,
# Nearest to grand: kristina, vytautas, maas, prix, obligate, rzeczypospolitej, kuznetsov, regents,
# Nearest to alternative: boying, pbs, additive, survivors, kcr, funkadelic, wray, used,
# Nearest to bbc: listing, feast, day, links, deane, news, broadcasts, gregorian,
# Nearest to quite: falla, anthropomorphic, much, reputation, lite, chelating, wakefulness, desperation,
# Nearest to universe: worlds, energies, cosmic, wildstorm, inflation, jin, amuck, simmons,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8125 0.0264 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8633 0.0252 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8173 0.0252 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8847 0.0253 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8561 0.0251 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8988 0.0251 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8931 0.0149 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8297 0.0254 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8600 0.0250 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8704 0.0251 sec/batch
# Nearest to their: they, them, to, any, plesiosaurs, horrifying, but, all,
# Nearest to were: was, had, could, early, have, as, been, for,
# Nearest to see: external, links, also, list, of, in, describing, iarc,
# Nearest to two: zero, three, five, one, four, seven, six, eight,
# Nearest to so: not, clear, abandon, depressed, adolfo, if, lidocaine, hopefully,
# Nearest to if: can, nhadau, iff, any, want, think, automatically, varphi,
# Nearest to into: the, first, and, called, which, eventually, depending, of,
# Nearest to new: york, outstripped, in, bonnie, the, based, that, conflicts,
# Nearest to stage: performed, arcane, formation, gametophyte, actors, autocracy, phases, videography,
# Nearest to additional: usually, qualitative, volleyball, glottis, okina, primary, vcore, postalveolar,
# Nearest to woman: fertility, adjective, infant, male, rate, nationality, expectancy, her,
# Nearest to grand: kristina, vytautas, maas, prix, obligate, regents, rzeczypospolitej, rump,
# Nearest to alternative: boying, pbs, complementary, additive, survivors, kcr, used, funkadelic,
# Nearest to bbc: listing, feast, day, deane, links, news, agatha, gregorian,
# Nearest to quite: falla, anthropomorphic, reputation, much, chelating, lite, wakefulness, feudatories,
# Nearest to universe: worlds, energies, wildstorm, cosmic, jin, inflation, indigenous, amuck,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8306 0.0267 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8424 0.0250 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8330 0.0250 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8214 0.0253 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8536 0.0251 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8308 0.0250 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9096 0.0253 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7700 0.0252 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8388 0.0252 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7982 0.0250 sec/batch
# Nearest to their: they, them, to, any, are, own, racemic, all,
# Nearest to were: was, could, had, early, have, least, been, as,
# Nearest to see: external, links, also, list, of, in, the, is,
# Nearest to two: zero, three, five, one, four, seven, eight, six,
# Nearest to so: not, abandon, depressed, when, gracefully, if, lidocaine, seamlessly,
# Nearest to if: can, any, iff, nhadau, automatically, a, so, want,
# Nearest to into: the, and, first, which, called, depending, eventually, of,
# Nearest to new: york, revised, in, outstripped, that, bonnie, logo, the,
# Nearest to stage: performed, actors, arcane, gametophyte, formation, autocracy, phases, videography,
# Nearest to additional: usually, volleyball, qualitative, primary, cleric, okina, metalloids, botanicals,
# Nearest to woman: fertility, adjective, infant, male, rate, nationality, expectancy, sexuality,
# Nearest to grand: kristina, vytautas, maas, prix, obligate, rzeczypospolitej, regents, heavy,
# Nearest to alternative: boying, pbs, funkadelic, kcr, additive, survivors, complementary, hens,
# Nearest to bbc: listing, feast, day, news, broadcasts, deane, links, bulletins,
# Nearest to quite: much, falla, lite, anthropomorphic, feudatories, chelating, reputation, developed,
# Nearest to universe: worlds, cosmic, energies, wildstorm, inflation, even, jin, simmons,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7794 0.0264 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8204 0.0251 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8557 0.0276 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8220 0.0252 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8188 0.0253 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9007 0.0257 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8752 0.0257 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8419 0.0255 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8461 0.0254 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8424 0.0252 sec/batch
# Nearest to their: they, them, to, own, any, are, however, advance,
# Nearest to were: was, could, early, had, have, as, least, for,
# Nearest to see: external, links, also, list, of, in, the, is,
# Nearest to two: zero, three, five, one, four, seven, six, eight,
# Nearest to so: depressed, abandon, gracefully, not, clear, adolfo, if, seamlessly,
# Nearest to if: can, any, nhadau, iff, varphi, automatically, want, adjudicate,
# Nearest to into: the, and, first, called, which, depending, eventually, tumbling,
# Nearest to new: york, outstripped, revised, that, lamarckian, in, bozeman, pennsylvania,
# Nearest to stage: performed, actors, arcane, formation, sarabande, gametophyte, autocracy, phases,
# Nearest to additional: usually, primary, volleyball, okina, qualitative, glottis, cleric, postalveolar,
# Nearest to woman: fertility, adjective, infant, male, rate, nationality, expectancy, sexuality,
# Nearest to grand: kristina, vytautas, prix, maas, obligate, rzeczypospolitej, regents, heavy,
# Nearest to alternative: boying, pbs, additive, kcr, complementary, used, funkadelic, survivors,
# Nearest to bbc: listing, day, feast, news, deane, links, bulletins, broadcasts,
# Nearest to quite: much, falla, lite, anthropomorphic, developed, feudatories, reputation, wakefulness,
# Nearest to universe: worlds, cosmic, energies, inflation, wildstorm, amuck, even, jin,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8821 0.0264 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8541 0.0250 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8268 0.0253 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8505 0.0252 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.9045 0.0252 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8555 0.0253 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8447 0.0252 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8459 0.0250 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8141 0.0250 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8179 0.0250 sec/batch
# Nearest to their: they, them, to, are, any, own, but, were,
# Nearest to were: was, had, could, early, have, as, for, these,
# Nearest to see: external, links, also, of, list, in, the, and,
# Nearest to two: zero, three, five, one, four, six, seven, eight,
# Nearest to so: when, not, if, abandon, always, adolfo, depressed, clear,
# Nearest to if: can, any, nhadau, so, want, iff, automatically, desecration,
# Nearest to into: the, and, first, which, called, eventually, from, of,
# Nearest to new: york, outstripped, revised, on, in, the, lamarckian, nine,
# Nearest to stage: performed, arcane, gametophyte, autocracy, actors, formation, sarabande, videography,
# Nearest to additional: usually, volleyball, cleric, okina, primary, botanicals, glottis, sayyed,
# Nearest to woman: fertility, adjective, infant, male, rate, nationality, expectancy, female,
# Nearest to grand: kristina, obligate, vytautas, prix, maas, regents, rzeczypospolitej, falsehoods,
# Nearest to alternative: boying, pbs, additive, kcr, survivors, complementary, used, limburg,
# Nearest to bbc: listing, feast, news, deane, day, broadcasts, links, bulletins,
# Nearest to quite: much, anthropomorphic, lite, falla, developed, reputation, some, wakefulness,
# Nearest to universe: worlds, energies, cosmic, wildstorm, inflation, amuck, jin, indigenous,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8493 0.0265 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8450 0.0251 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9209 0.0251 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9235 0.0251 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8749 0.0249 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8516 0.0250 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7752 0.0249 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8532 0.0249 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7754 0.0249 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8826 0.0251 sec/batch
# Nearest to their: they, them, any, own, to, are, plesiosaurs, but,
# Nearest to were: was, had, could, early, have, as, been, in,
# Nearest to see: external, links, also, of, list, in, the, a,
# Nearest to two: zero, three, five, one, four, six, seven, eight,
# Nearest to so: not, if, when, always, adolfo, kam, depressed, abandon,
# Nearest to if: can, any, so, iff, nhadau, homeomorphic, want, think,
# Nearest to into: the, and, first, called, which, depending, eventually, tumbling,
# Nearest to new: york, outstripped, on, revised, the, in, one, based,
# Nearest to stage: performed, actors, gametophyte, arcane, videography, autocracy, entertainers, formation,
# Nearest to additional: usually, volleyball, okina, glottis, cleric, botanicals, sayyed, annotated,
# Nearest to woman: fertility, adjective, infant, male, rate, nationality, expectancy, her,
# Nearest to grand: kristina, vytautas, obligate, prix, rzeczypospolitej, regents, maas, kuznetsov,
# Nearest to alternative: boying, pbs, additive, used, kcr, funkadelic, complementary, quieter,
# Nearest to bbc: listing, day, feast, links, news, agatha, deane, broadcasts,
# Nearest to quite: falla, lite, much, anthropomorphic, reputation, wakefulness, developed, some,
# Nearest to universe: worlds, energies, wildstorm, cosmic, jin, inflation, amuck, even,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8643 0.0264 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8372 0.0249 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
